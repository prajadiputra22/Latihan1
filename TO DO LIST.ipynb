# %%
kegiatan = []
i = 0

while True :
    print('\nAplikasi To Do List')
    print('By : Darmawan SP\n')
    print('''1. Tambah Kegiatan
2. Hapus Kegiatan
3. Exit\n''')
    
    opt = int(input('Masukan pilihan :'))
   
    if opt == 1 :
         while True :
            kegiatan_baru = input("Masukan kegiatan : ")
            kegiatan.append(kegiatan_baru)

            i += 1
        
            tanya = input("Tambah kegiatan lagi? (y/n): ")
            if tanya == "n":
                print ("\nKamu memiliki {} kegiatan :".format(len(kegiatan)))
                for kg in kegiatan :
                    print ("- {}".format(kg))
                break
                
    elif opt == 2 :
        while True :
            kegiatan.remove(input('\nMasukan kegiatan yang akan dihapus : '))

            i -= 1

            tanya = input("Ada yang ingin dihapus lagi? (y/n): ")
            if tanya == "n":
                print ("\nKamu memiliki {} kegiatan :".format(len(kegiatan)))
                for kg in kegiatan :
                     print ("- {}".format(kg))
                break
                
    elif opt == 3 :
        tanya = input('\nApakah anda ingin keluar? (y/n) :')
        if tanya== 'y' :
            print('Terima kasih telah menggunakan program ini'.upper())
            break
        else : continue
            
    else :
        print('EROR - Mohon masukan nomor dengan benar.')
# Out:
# Aplikasi To Do List
# By : Darmawan SP
#
# 1. Tambah Kegiatan
# 2. Hapus Kegiatan
# 3. Exit
#
# Masukan pilihan :1
# Masukan kegiatan : main bola
# Tambah kegiatan lagi? (y/n): y
# Masukan kegiatan : main basket
# Tambah kegiatan lagi? (y/n): y
# Masukan kegiatan : maen voli
# Tambah kegiatan lagi? (y/n): n
#
# Kamu memiliki 3 kegiatan :
# - main bola
# - main basket
# - maen voli
#
# Aplikasi To Do List
# By : Darmawan SP
#
# 1. Tambah Kegiatan
# 2. Hapus Kegiatan
# 3. Exit
#
# Masukan pilihan :2
#
# Masukan kegiatan yang akan dihapus : main bola
# Ada yang ingin dihapus lagi? (y/n): y
#
# Masukan kegiatan yang akan dihapus : main basket
# Ada yang ingin dihapus lagi? (y/n): n
#
# Kamu memiliki 1 kegiatan :
# - maen voli
#
# Aplikasi To Do List
# By : Darmawan SP
#
# 1. Tambah Kegiatan
# 2. Hapus Kegiatan
# 3. Exit
#
# Masukan pilihan :5
# EROR - Mohon masukan nomor dengan benar.
#
# Aplikasi To Do List
# By : Darmawan SP
#
# 1. Tambah Kegiatan
# 2. Hapus Kegiatan
# 3. Exit
#
# Masukan pilihan :3
#
# Apakah anda ingin keluar? (y/n) :y
# TERIMA KASIH TELAH MENGGUNAKAN PROGRAM INI
